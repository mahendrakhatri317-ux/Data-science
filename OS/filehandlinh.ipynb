# %%
import os

# %%
file = open("simple.txt", "w")
file.write("hii how are you")
file.close()
file = open("simple.txt", "r")
file.read()
# Out:
# 'hii how are you'

# %%
file =open("simple.txt", "a")
file.write("free sample TXT files for development and testing. Various content types available, including long documents, ASCII art, and multi-language text")
file.close()

# %%
open("simple.txt", "r").read()
# Out:
# 'hii how are youfree sample TXT files for development and testing. Various content types available, including long documents, ASCII art, and multi-language text'

# %%
file =open("filehandling.txt", "w")
file.write("free sample TXT files for development and testing. Various content types available, including long documents, ASCII art, and multi-language text")
file.close()

# %%
#file.read() --- IGNORE ---

# %%
file =open("filehandling1.txt", "x")
file.write("free sample TXT files for development and testing. Various content types available, including long documents, ASCII art, and multi-language text")
file.close()
