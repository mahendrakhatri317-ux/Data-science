# %% [markdown]
# #  OS module in python
# Python ka os module operating system ke saath interact karne ke liye use hota hai.
# Isse hum:
# * folders/files create kar sakte hain
# * rename/delete kar sakte hain
# * current directory check kar sakte hain
# * system commands run kar sakte hain
#
# ## all important command's
#
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |

# %%
# import os moodule
import os

# %% [markdown]
# ### 1. Current Working Directory
#
# Current folder ka path dikhata hai.

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Jaishree\OneDrive\Pictures\Camera Roll\cunstrocter

# %% [markdown]
# ### 2. Change Directory
#
# Directory change karne ke liye.

# %%
import os

os.chdir(r"C:\Users\Jaishree\OneDrive\Pictures\Camera Roll\cunstrocter")
print(os.getcwd())
# Out:
# C:\Users\Jaishree\OneDrive\Pictures\Camera Roll\cunstrocter

# %% [markdown]
# ### 3. Create Folder
# os.mkdir()
#
# Single folder create karta hai.

# %%
import os

os.mkdir("NewFolder")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 import os
#       2
# ----> 3 os.mkdir("NewFolder")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'NewFolder'

# %% [markdown]
# ### 4. Create Multiple Folders
# os.makedirs()

# %%
import os

os.makedirs("gita/babita/dangle")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 import os
#       2
# ----> 3 os.makedirs("gita/babita/dangle")
#
# File <frozen os>:230, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'gita/babita/dangle'

# %% [markdown]
# ### 5. Remove Folder
# os.rmdir()

# %%
import os

os.rmdir("rohit")

# %% [markdown]
# ### 6. Remove Multiple Folders
# os.removedirs()

# %%
import os

os.removedirs("gita/babita/dangle")

# %% [markdown]
# ### 7. Rename File or Folder
# os.rename()

# %%
import os

os.rename("rohit.txt", "montu.txt")

# %% [markdown]
# ### 8. List Files and Folders
# os.listdir()

# %%
import os

print(os.listdir())
# Out:
# ['2.png', '3.png', '4.png', '5.png', 'gita', 'New folder', 'rohit', 'Screenshot 2026-05-23 234059.png']

# %% [markdown]
# ### 9. Check File Exists or Not

# %%
import os

print(os.path.exists(r"C:\Users\Jaishree\OneDrive\ドキュメント\weather project\.qodo"))
# Out:
# True

# %% [markdown]
# ### 10. File Size

# %%
import os

size = os.path.getsize(r"C:\Users\Jaishree\OneDrive\ドキュメント\weather project\.qodo")
print(size)
# Out:
# 4096

# %% [markdown]
# ### 11. OS Name

# %%
import os

print(os.name)
# Out:
# nt

# %% [markdown]
# ### 12. Join Paths
# os.path.join()

# %%
import os

path = os.path.join(r"C:\Users\Jaishree\OneDrive\Pictures\Camera Roll",r"C:\Users\Jaishree\OneDrive\Desktop\web design\html",r"C:\Users\Jaishree\OneDrive\ドキュメント\weather project\.qodo")

print(path)
# Out:
# C:\Users\Jaishree\OneDrive\ドキュメント\weather project\.qodo

# %% [markdown]
# ### 13. Absolute Path

# %%
import os

print(os.path.abspath(r"C:\Users\Jaishree\OneDrive\ドキュメント\weather project\.qodo"))
# Out:
# C:\Users\Jaishree\OneDrive\ドキュメント\weather project\.qodo
