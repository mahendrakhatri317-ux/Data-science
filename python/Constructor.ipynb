# %% [markdown]
# # Constructor in Python
# Constructor ek special function hota hai jo object create hote hi automatically call ho jata hai.
# Python me constructor ko __init__() likhte hain.

# %%
print("Constructor")
# Out:
# Constructor

# %%
class Collage:
    def __init__(self):
        pass

# %%
class Collage:
    def __init__(self):
        pass
clg =Collage()

# %%
class Collage:
    def __init__(self):
        collage_name = "Arya main campus"
clg =Collage()

# %%
class Collage:
    def __init__(self):
        self.collage_name = "Arya main campus" ### instance variable 
        self.collage_address = "jaipur" ### instance variable 
        self.collage_sp = "42" ### instance variable 
        # self.collage_n = "Arya main campus" ### instance variable 
        # self.collage_name = "Arya main campus" ### instance variable 
        
clg =Collage()

# %%
clg.collage_name
# Out:
# 'Arya main campus'

# %%
clg.collage_address
# Out:
# 'jaipur'

# %%
clg.collage_sp
# Out:
# '42'

# %%
class Student:
    def __init__(self, name , branch, roll_number, classes):
        self.name= name 
        self.branch = branch
        self.roll_number = roll_number
        self.classes = classes
        
    def display(self):
        pass
clg =Student(name="Govind", branch="CSE", roll_number="21eaycs055", classes="4th year")

# %%
ritik_data  =Student(name="Ritik", branch="CSE", roll_number="21eaycs052", classes="4th year")

# %%
ritik_data.name
# Out:
# 'Ritik'

# %%
clg.classes
# Out:
# '4th year'

# %%
clg.branch
# Out:
# 'CSE'

# %%
clg.display()

# %%
class Student:
    def __init__(self, name , branch, roll_number, classes):
        self.name= name 
        self.branch = branch
        self.roll_number = roll_number
        self.classes = classes
        
    def display(self):
        print(self.name)
        pass
clg =Student(name="Govind", branch="CSE", roll_number="21eaycs055", classes="4th year")

# %%
clg.display()
# Out:
# Govind

# %%
class Student:
    def __init__(self, name , branch, roll_number, classes):
        self.name= name 
        self.branch = branch
        self.roll_number = roll_number
        self.classes = classes
class Collage(Student):
    def __init__(self, name1 , branch1):
        self.name= name1 
        self.branch = branch1
        # self.roll_number = roll_number
        # self.classes = classes
        
class Hello(Collage):
    def __init__(self):
        pass
        self.name= name 
        self.branch = branch
        # self.roll_number = roll_number
        # self.classes = classes
clg = Collage(name1="Govind", branch1="CSE")
print(clg.name)
print(clg.branch)
# Out:
# Govind
# CSE
