# %%
pip install pandas

# %% [markdown]
# # Pandas
#
# Pandas ek powerful Python library hai jo:
#
# * data ko read karne
# * organize karne
# * clean karne
# * analyze karne
# * manipulate karne
#
# ke liye use hoti hai.
#
# Ye specially Data Science, Machine Learning, aur Data Analysis me use hoti hai.
# Pandas me table ko DataFrame bolte hain.
#
# ### Data Science me use
#
# Pandas ka use:
#
# * CSV files
# * Excel files
# * Data cleaning
# * Data analysis
#
# Machine Learning preprocessing me hota hai.
#
# | Term      | Meaning              |
# | --------- | -------------------- |
# | Series    | Single column        |
# | DataFrame | Complete table       |
# | CSV       | Comma separated file |

# %%
import os
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Jaishree\Downloads\Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name   price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1               Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                      Triumph Daytona 675R  600000      Delhi         110
# 3                      TVS Apache RTR 180cc   65000  Bangalore       16329
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                     ...     ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000      Delhi       22000
# 32644                  TVS Apache RTR 180cc   30000     Karnal        6639
# 32645              Bajaj Avenger Street 220   60000      Delhi       20373
# 32646             Hero Super Splendor 125cc   15600     Jaipur       84186
# 32647                    Bajaj Pulsar 150cc   22000       Pune       60857
#
#              owner  age  power          brand
# ...

# %%
df.head()
# Out:
#                               bike_name   price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1           Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                  Triumph Daytona 675R  600000      Delhi         110
# 3                  TVS Apache RTR 180cc   65000  Bangalore       16329
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
#
#          owner  age  power          brand
# 0  First Owner    3    110            TVS
# 1  First Owner    4    350  Royal Enfield
# 2  First Owner    8    675        Triumph
# 3  First Owner    4    180            TVS
# 4  First Owner    3    150         Yamaha

# %%
df.head(10)
# Out:
#                                   bike_name   price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1               Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                      Triumph Daytona 675R  600000      Delhi         110
# 3                      TVS Apache RTR 180cc   65000  Bangalore       16329
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# 5                          Yamaha FZs 150cc   53499      Delhi       25000
# 6             Honda CB Hornet 160R  ABS DLX   85000      Delhi        8200
# 7       Hero Splendor Plus Self Alloy 100cc   45000      Delhi       12645
# 8         Royal Enfield Thunderbird X 350cc  145000  Bangalore        9190
# 9  Royal Enfield Classic Desert Storm 500cc   88000      Delhi       19000
#
#           owner  age  power          brand
# 0   First Owner    3    110            TVS
# 1   First Owner    4    350  Royal Enfield
# ...

# %%
df.tail()
# Out:
#                        bike_name  price    city  kms_driven        owner  age  \
# 32643     Hero Passion Pro 100cc  39000   Delhi       22000  First Owner    4
# 32644       TVS Apache RTR 180cc  30000  Karnal        6639  First Owner    9
# 32645   Bajaj Avenger Street 220  60000   Delhi       20373  First Owner    6
# 32646  Hero Super Splendor 125cc  15600  Jaipur       84186  First Owner   16
# 32647         Bajaj Pulsar 150cc  22000    Pune       60857  First Owner   13
#
#        power  brand
# 32643    100   Hero
# 32644    180    TVS
# 32645    220  Bajaj
# 32646    125   Hero
# 32647    150  Bajaj

# %%
df.tail(15)
# Out:
#                              bike_name   price                 city  \
# 32633      Royal Enfield Classic 350cc   87000  Gautam Buddha Nagar
# 32634  Royal Enfield Thunderbird 350cc   70000               Mumbai
# 32635                Suzuki Zeus 125cc   35000            Ahmedabad
# 32636                     KTM RC 390cc  196700               Mumbai
# 32637               Bajaj Pulsar 150cc   25000                Delhi
# 32638            Yamaha Fazer 25 250cc  123000               Kadapa
# 32639      Royal Enfield Classic 350cc   95500                Delhi
# 32640           Hero Passion Pro 100cc   32000                Delhi
# 32641              Bajaj Avenger 220cc   41000                Delhi
# 32642               Hero Passion 100cc   15000          Perumbavoor
# 32643           Hero Passion Pro 100cc   39000                Delhi
# 32644             TVS Apache RTR 180cc   30000               Karnal
# 32645         Bajaj Avenger Street 220   60000                Delhi
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  int64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  int64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  int64
#  6   power       32648 non-null  int64
#  7   brand       32648 non-null  str
# dtypes: int64(4), str(4)
# memory usage: 2.0 MB

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='str')

# %%
df['age']
# Out:
# 0         3
# 1         4
# 2         8
# 3         4
# 4         3
#          ..
# 32643     4
# 32644     9
# 32645     6
# 32646    16
# 32647    13
# Name: age, Length: 32648, dtype: int64

# %%
df['brand']
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: str

# %%
df[['brand']]
# Out:
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# 32644            TVS
# 32645          Bajaj
# 32646           Hero
# 32647          Bajaj
#
# [32648 rows x 1 columns]

# %%
df[['brand','age']]
# Out:
#                brand  age
# 0                TVS    3
# 1      Royal Enfield    4
# 2            Triumph    8
# 3                TVS    4
# 4             Yamaha    3
# ...              ...  ...
# 32643           Hero    4
# 32644            TVS    9
# 32645          Bajaj    6
# 32646           Hero   16
# 32647          Bajaj   13
#
# [32648 rows x 2 columns]

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df['city'].unique()
# Out:
# <StringArray>
# [   'Ahmedabad',        'Delhi',    'Bangalore',       'Mumbai',
#        'Kalyan',    'Faridabad',       'Mettur',    'Hyderabad',
#       'Kaithal',      'Gurgaon',
#  ...
#   'Bhubaneswar',      'Raiganj', 'Bhilai Nagar',       'Baloda',
#      'Anantnag',   'Berhampore',      'Silvasa',       'Hospet',
#         'Palai',        'Sidhi']
# Length: 443, dtype: str

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# LML                    1
# Yezdi                  1
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates()
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#       bike_name  price   city  kms_driven  owner    age  power  brand
# 0         False  False  False       False  False  False  False  False
# 1         False  False  False       False  False  False  False  False
# 2         False  False  False       False  False  False  False  False
# 3         False  False  False       False  False  False  False  False
# 4         False  False  False       False  False  False  False  False
# ...         ...    ...    ...         ...    ...    ...    ...    ...
# 9362      False  False  False       False  False  False  False  False
# 9369      False  False  False       False  False  False  False  False
# 9370      False  False  False       False  False  False  False  False
# 9371      False  False  False       False  False  False  False  False
# 9372      False  False  False       False  False  False  False  False
#
# [7324 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   int64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   int64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   int64
#  6   power       7324 non-null   int64
#  7   brand       7324 non-null   str
# dtypes: int64(4), str(4)
# memory usage: 515.0 KB

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict={0:'First Owner',1:'Second Owner',2:'Third Owner',3:'Fourth & Above Owner',4:'Test Drive Car'}

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   int64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   int64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   int64
#  6   power       7324 non-null   int64
#  7   brand       7324 non-null   str
# dtypes: int64(4), str(4)
# memory usage: 515.0 KB

# %%
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
brand_dict = {
     'TVS':1, 'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23
}

# %%
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   int64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   int64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   int64
#  6   power       7324 non-null   int64
#  7   brand       7324 non-null   str
# dtypes: int64(4), str(4)
# memory usage: 515.0 KB

# %%
obj_val =df.select_dtypes(include='O')
# Out:
# C:\Users\Jaishree\AppData\Local\Temp\ipykernel_3932\2170337667.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val =df.select_dtypes(include='O')

# %%
obj_val
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...

# %%
num_val =df.select_dtypes(exclude='O')

# %%
num_val
# Out:
#        price  kms_driven  age  power
# 0      35000       17654    3    110
# 1     119900       11000    4    350
# 2     600000         110    8    675
# 3      65000       16329    4    180
# 4      80000       10000    3    150
# ...      ...         ...  ...    ...
# 9362   25000       48587    8    150
# 9369   35000       60000    9    220
# 9370  450000        3430    4    750
# 9371  139000       21300    4    400
# 9372   80000        7127    5    220
#
# [7324 rows x 4 columns]

# %%
complete_Data =pd.concat([obj_val, num_val], axis=1)

# %%
complete_Data
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand   price  kms_driven  age  power
# 0                 TVS   35000       17654    3    110
# ...

# %%
tvs_brand =df[df['brand']=='TVS']

# %%
tvs_brand['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner']
# Length: 3, dtype: str

# %%
# brand = " royal", km = >50Km, owner = 1st, age 2 sal se km

# %%
tvs_first =tvs_brand[tvs_brand['owner']=='First Owner']

# %%
tvs_first[tvs_first['age']<=2]
# Out:
#                                               bike_name   price  \
# 193                  TVS Apache RTR 160 4V DISC ABS BS6   85000
# 360                          TVS Apache RTR 160 4V Disc   78700
# 401              TVS Apache RTR 200 4V ABS Race Edition  108500
# 425                      TVS Apache RTR 160 4V DISC ABS   87000
# 511                      TVS Apache RTR 160 4V DRUM ABS   85000
# 594                      TVS Apache RTR 160 4V DISC ABS   91800
# 664                      TVS Apache RTR 160 4V DISC ABS   89000
# 757                          TVS Apache RTR 160 4V Disc   74700
# 1097  TVS Apache RTR 200 4V Carburetor Race Edition 2.0   93500
# 1126         TVS Apache RTR 200 4V Dual Channel ABS BS6  130000
# 1132                 TVS Apache RTR 160 4V DISC ABS BS6   98000
# 1171                                   TVS Apache RR310  200000
# 1318             TVS Apache RTR 200 4V ABS Race Edition  125000
# 1514            TVS Apache RTR 160cc Matt Red Rear Disc   76000
# ...

# %%
df
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#             owner  age  power            brand
# ...

# %%
tvvs_brand=df[df['brand']=='TVS']

# %%
tvs_under2 =tvs_brand[tvvs_brand['age']<=2]

# %%
df[(df['brand']=='Royal Enfield') & (df['age']<=2) ]
# Out:
#                                          bike_name   price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300      Vadodara
# 194                    Royal Enfield Electra 350cc  145000     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982  Hamirpur(hp)
# ...                                            ...     ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
tvs_under2[tvs_under2['kms_driven']<=20000]
# Out:
#                                               bike_name   price       city  \
# 193                  TVS Apache RTR 160 4V DISC ABS BS6   85000  Hyderabad
# 360                          TVS Apache RTR 160 4V Disc   78700   Rudrapur
# 401              TVS Apache RTR 200 4V ABS Race Edition  108500      Delhi
# 425                      TVS Apache RTR 160 4V DISC ABS   87000      Delhi
# 511                      TVS Apache RTR 160 4V DRUM ABS   85000    Gurgaon
# 594                      TVS Apache RTR 160 4V DISC ABS   91800      Delhi
# 664                      TVS Apache RTR 160 4V DISC ABS   89000      Delhi
# 1097  TVS Apache RTR 200 4V Carburetor Race Edition 2.0   93500  Bangalore
# 1126         TVS Apache RTR 200 4V Dual Channel ABS BS6  130000  Bangalore
# 1132                 TVS Apache RTR 160 4V DISC ABS BS6   98000     Jaipur
# 1171                                   TVS Apache RR310  200000     Mumbai
# ...

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='str')

# %%
# df[(df['brand']=='Royal Enfield') & (df['age']<=2) & (df['price']<150000) ]
df.query("brand=='Royal Enfield' and age <=2")
# Out:
#                                          bike_name   price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300      Vadodara
# 194                    Royal Enfield Electra 350cc  145000     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982  Hamirpur(hp)
# ...                                            ...     ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
df.drop(['bike_name', 'city'], axis=1, inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(18)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# price         0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
x =df.drop('price', axis=1)

# %%
y =df[['price']]

# %%
y
# Out:
#        price
# 0      35000
# 1     119900
# 2     600000
# 3      65000
# 4      80000
# ...      ...
# 9362   25000
# 9369   35000
# 9370  450000
# 9371  139000
# 9372   80000
#
# [7306 rows x 1 columns]

# %%
x
# Out:
#       kms_driven        owner  age  power            brand
# 0          17654  First Owner    3    110              TVS
# 1          11000  First Owner    4    350    Royal Enfield
# 2            110  First Owner    8    675          Triumph
# 3          16329  First Owner    4    180              TVS
# 4          10000  First Owner    3    150           Yamaha
# ...          ...          ...  ...    ...              ...
# 9362       48587  First Owner    8    150             Hero
# 9369       60000  First Owner    9    220            Bajaj
# 9370        3430  First Owner    4    750  Harley-Davidson
# 9371       21300  First Owner    4    400            Bajaj
# 9372        7127  First Owner    5    220            Bajaj
#
# [7306 rows x 5 columns]

# %%
df
# Out:
#        price  kms_driven        owner  age  power            brand
# 0      35000       17654  First Owner    3    110              TVS
# 1     119900       11000  First Owner    4    350    Royal Enfield
# 2     600000         110  First Owner    8    675          Triumph
# 3      65000       16329  First Owner    4    180              TVS
# 4      80000       10000  First Owner    3    150           Yamaha
# ...      ...         ...          ...  ...    ...              ...
# 9362   25000       48587  First Owner    8    150             Hero
# 9369   35000       60000  First Owner    9    220            Bajaj
# 9370  450000        3430  First Owner    4    750  Harley-Davidson
# 9371  139000       21300  First Owner    4    400            Bajaj
# 9372   80000        7127  First Owner    5    220            Bajaj
#
# [7306 rows x 6 columns]

# %%
df.to_csv("clean_bike_data.csv")

# %%
df
# Out:
#        price  kms_driven        owner  age  power            brand
# 0      35000       17654  First Owner    3    110              TVS
# 1     119900       11000  First Owner    4    350    Royal Enfield
# 2     600000         110  First Owner    8    675          Triumph
# 3      65000       16329  First Owner    4    180              TVS
# 4      80000       10000  First Owner    3    150           Yamaha
# ...      ...         ...          ...  ...    ...              ...
# 9362   25000       48587  First Owner    8    150             Hero
# 9369   35000       60000  First Owner    9    220            Bajaj
# 9370  450000        3430  First Owner    4    750  Harley-Davidson
# 9371  139000       21300  First Owner    4    400            Bajaj
# 9372   80000        7127  First Owner    5    220            Bajaj
#
# [7306 rows x 6 columns]
